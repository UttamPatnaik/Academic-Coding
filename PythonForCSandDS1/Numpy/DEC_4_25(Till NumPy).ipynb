# %%
import numpy as np
num=np.arange(1,6)
num
# Out:
# array([1, 2, 3, 4, 5])

# %%
num2=num.view()
num2
# Out:
# array([1, 2, 3, 4, 5])

# %%
num3=num.copy()
num3
# Out:
# array([1, 2, 3, 4, 5])

# %%
num[1]*=10
num
# Out:
# array([ 1, 20,  3,  4,  5])

# %%
numbers2 = num[0:3]
numbers2
# Out:
# array([ 1, 20,  3])

# %%
#Shallow caopy the array method view returna new array objedct with a view of the original arrqay
#objerct data
#Both reshape and resize chnage the array dimensitons, reshape returns a view(shallow copy) of the
#original array with new dimensions, doesnt modify the original aray
#Resize modifies the original array

# %%
import numpy as np
grades = np.array([[87, 96, 70], [100,87, 90]])
grades
# Out:
# array([[ 87,  96,  70],
#        [100,  87,  90]])

# %%
grades.reshape(1, 6)
# Out:
# array([[ 87,  96,  70, 100,  87,  90]])

# %%
grades.resize(1, 6)
grades
# Out:
# array([[ 87,  96,  70, 100,  87,  90]])

# %%
#flatten fucntion is used to flattehn a mutli dim array uinto 1 dim
#deepcopies original array data
#ravel also converts multi dim to signle dim,
#shallow copies original array

# %%
grades = np.array([[87, 96, 70], [100,87, 90]])
grades
# Out:
# array([[ 87,  96,  70],
#        [100,  87,  90]])

# %%
flattened = grades.flatten()
flattened
# Out:
# array([ 87,  96,  70, 100,  87,  90])

# %%
flattened[0] = 100
flattened
# Out:
# array([100,  96,  70, 100,  87,  90])

# %%
grades
# Out:
# array([[ 87,  96,  70],
#        [100,  87,  90]])

# %%
grades = np.array([[87, 96, 70], [100,87, 90]])
raveled = grades.ravel()
raveled
# Out:
# array([ 87,  96,  70, 100,  87,  90])

# %%
grades
# Out:
# array([[ 87,  96,  70],
#        [100,  87,  90]])

# %%
raveled[0] = 100
raveled
# Out:
# array([100,  96,  70, 100,  87,  90])

# %%
grades

# %%
#stacking means combining arrasys by adding more columns and more rows(2 types- horizontal and vertical)

# %%
grades2 = np.array([[94, 77, 90], [100,81, 82]])
np.hstack((grades,grades2))
# Out:
# array([[ 87,  96,  70,  94,  77,  90],
#        [100,  87,  90, 100,  81,  82]])

# %%
np.vstack((grades,grades2))
# Out:
# array([[ 87,  96,  70],
#        [100,  87,  90],
#        [ 94,  77,  90],
#        [100,  81,  82]])

# %%
grades2.T
# Out:
# array([[ 94, 100],
#        [ 77,  81],
#        [ 90,  82]])
