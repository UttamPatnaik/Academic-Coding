# %% [markdown]
# # Python for Computer Science and Data Science 1 (CSE 3651)
#
# # MINOR ASSIGNMENT-2: CONTROL STATEMENTS AND PROGRAM DEVELOPMENT

# %%
"""1. Write a program such that Python will ask you if it is raining or not. If your answer is ”yes”, Python
will say ”Carry an umbrella”. If you type anything else, Python will say ”Bye”."""

Msg=input("Is it raining?")
if Msg=="Yes":
    print("Carry an Umbrella")
else:
    print("Bye")

# %%
"""2. Write a program such that Python will ask you if it is raining or not. If your answer is ”yes”, Python
will say ”Carry an umbrella”. If you say ”no”, Python will say ”No need to carry an umbrella”. If
you type anything else, Python will say ”Bye”."""

Msg=input("Is it raining?")
if Msg=="Yes":
    print("Carry an Umbrella")
elif Msg=="No":
    print("No need to carry an umbrella")
else:
    print("Bye")

# %%
"""3.
Part1: Write a Python program to calculate a student’s letter grade based on their numeric score using the fol-
lowing scale: A (90–100), B (80–89), C (70–79), D (60–69), and F (below 60). Additionally, provide
a comment for each grade: ”Excellent” for A, ”Good” for B, ”Average” for C, ”Needs Improvement”
for D, and ”Failing” for F."""

mark=int(input("Enter the marks: "))
assert mark>=0 and mark<=100
if mark>=90 and mark<=100:
    print("Grade: A \n Remarks: Excellent")
elif mark>=80 and mark<=89:
    print("Grade: B \n Remarks: Good")
elif mark>=70 and mark<=79:
    print("Grade: C \n Remarks: Average")
elif mark>=60 and mark<=69:
    print("Grade: D \n Remarks: Needs Improvement")
else:
    print("Grade: E \n Remarks: Failing")

"""Part2: Write a program that reads the lengths of the three sides of a triangle from the user. Then display a
message that states the triangles type."""

a=int(input("Enter the length of side 1"))
b=int(input("Enter the length of side 2"))
c=int(input("Enter the length of side 3"))
if(a+b>=c and b+c>=a and c+a>=b):
    if(a==b==c):
        print("It is an Equilateral Triangle")
    elif a==b or b==c or c==a:
        print("It is an Equilateral Triangle")
    else:
        print("It is an Scalene Triangle")
# Out:
# Enter the marks: 89
# Grade: B
#  Remarks: Good
# Grade: E
#  Remarks: Failing

# %%
"""4. Write a program that takes an integer input from the user and tells the user whether the number is
even or odd."""

n=int(input("Enter a number: "))
if(n%2==0):
    print("It is an even number")
else:
    print("It is an even number")

# %%
"""5. Write a program that takes a year as input and determines whether it is a leap year or not."""

year=int(input("Enter a year: "))
if(year%4==0 and year%100!=0 or year%400==0):
    print("It is a leap year")
else:
    print("It is not a leap year")

# %%
"""6. Write a program that takes an integer input from the user and prints whether it is prime or not."""

pcn=int(input("Enter a number: "))
c=0
for i in range(0,pcn):
    if(pcn%i==0):
        c+=1
if(c==2):
    print("It is a prime number.")
else: 
    print("It is a composite number.")

# %%
"""7. In line with the previous question, write a program to compute the sum of all prime numbers below a
user input number, e.g., Sum of all prime numbers less than 20 is 77."""

lr=int(input("Enter a number: "))
s=0
assert lr>=2
for i in range(2,lr):
    c=0
    for j in range(1,i+1):
        if(i%j==0):
            c+=1
    if(c==2):
        s+=i
print(f"Sum of all prime numbers less than {lr} is: {s}")
# Out:
# Enter a number: 20
# Sum of all prime numbers less than 20 is: 77

# %%
"""8. Write a program that takes an integer input from the user. Use a while loop to continuously prompt
for input until the user enters a positive number. If the final number is even, multiply it by 2 and if it
is odd, square it. Display the results at the end."""
b=True
while(b):
    n=int(input("Enter a number: "))
    if(n>0):
        b=False
if(n%2==0):
    print(f"An Even Positive Number is entered \nResult: {n*2}")
else:
    print(f"An Odd Positive Number is entered \nResult: {n*n}")
# Out:
# Enter a number: -9
# Enter a number: -8
# Enter a number: -7
# Enter a number: 8
# An Even Positive Number is entered
#  Result: 16

# %%
"""9. Write a program to find the remainder when a user input number is divided by 5 using match case. If
the user inputs a non-integer, Python should say ”Invalid input” and stop."""

n = int(input("Enter a number: "))
r = n % 5
match r:
    case 0:
        print(f"{n}, when divided by 5 gives remainder {r}")
    case 1:
        print(f"{n}, when divided by 5 gives remainder {r}")
    case 2:
        print(f"{n}, when divided by 5 gives remainder {r}")
    case 3:
        print(f"{n}, when divided by 5 gives remainder {r}")
    case 4:
        print(f"{n}, when divided by 5 gives remainder {r}")
# Out:
#   Cell In[2], line 6
#     match r:
#           ^
# SyntaxError: invalid syntax

# %%
"""10. Write a program that takes a string as input and prints out all possible sub strings of the string using
loops, e.g., if the input is ”abc”, the output should be ”a”, ”ab”, ”abc”, ”b”, ”bc”, ”c”."""

s=input("Enter a String")
