# %% [markdown]
# # Chapter-13 Twitter
#
# ## Tweepy Functions

# %% [markdown]
# ### Write a Python code to fetch user details including follower count from Twitter's API using the tweepy package and authetication credentials

# %%
pip install tweepy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for tweepy from https://files.pythonhosted.org/packages/ee/7c/3375cd1fbefcb8ead580fe324b1b6dcdc21aabf51562ee6def7266fcf363/tweepy-4.16.0-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for oauthlib<4,>=3.2.0 from https://files.pythonhosted.org/packages/be/9c/92789c596b8df838baa98fa71844d84283302f7604ed565dafe5a6b5041a/oauthlib-3.3.1-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for requests-oauthlib<3,>=1.2.0 from https://files.pythonhosted.org/packages/3b/5d/63d4ae3b9daea098d5d6f5da83984853c1bbacd5dc826764b249fe119d24/requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.8/98.8 kB 2.3 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.1/160.1 kB 4.9 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
